# %% [markdown]
# <hr style="height:2px;">
#
# # Demo: Neural network training for denoising of *Tribolium castaneum*
#
# This notebook demonstrates training a CARE model for a 3D denoising task, assuming that training data was already generated via [1_datagen.ipynb](1_datagen.ipynb) and has been saved to disk to the file ``data/my_training_data.npz``.
#
# Note that training a neural network for actual use should be done on more (representative) data and with more training time.
#
# More documentation is available at http://csbdeep.bioimagecomputing.com/doc/.

# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
# Out:
# 2022-07-19 12:40:24.175089: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# The TensorFlow backend uses all available GPU memory by default, hence it can be useful to limit it:

# %%
# limit_gpu_memory(fraction=1/2)

# %% [markdown]
# <hr style="height:2px;">
#
# # Training data
#
# Load training data generated via [1_datagen.ipynb](1_datagen.ipynb), use 10% as validation data.

# %%
(X,Y), (X_val,Y_val), axes = load_training_data('data/my_training_data.npz', validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 922
# number of validation images:	 102
# image size (3D):		 (16, 64, 64)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %% [markdown]
# <hr style="height:2px;">
#
# # CARE model
#
# Before we construct the actual CARE model, we have to define its configuration via a `Config` object, which includes
# * parameters of the underlying neural network,
# * the learning rate,
# * the number of parameter updates per epoch,
# * the loss function, and
# * whether the model is probabilistic or not.
#
# The defaults should be sensible in many cases, so a change should only be necessary if the training process fails.
#
# ---
#
# <span style="color:red;font-weight:bold;">Important</span>: Note that for this notebook we use a very small number of update steps per epoch for immediate feedback, whereas this number should be increased considerably (e.g. `train_steps_per_epoch=400`) to obtain a well-trained model.

# %%
config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=10)
print(config)
vars(config)
# Out:
# Config(axes='ZYXC', n_channel_in=1, n_channel_out=1, n_dim=3, probabilistic=False, train_batch_size=16, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0}, train_steps_per_epoch=10, train_tensorboard=True, unet_input_shape=(None, None, None, 1), unet_kern_size=3, unet_last_activation='linear', unet_n_depth=2, unet_n_first=32, unet_residual=True)
# {'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'probabilistic': False,
#  'unet_residual': True,
#  'unet_n_depth': 2,
#  'unet_kern_size': 3,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, None, 1),
#  'train_loss': 'mae',
#  'train_epochs': 100,
#  'train_steps_per_epoch': 10,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 16,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10, 'min_delta': 0}}

# %% [markdown]
# We now create a CARE model with the chosen configuration:

# %%
model = CARE(config, 'my_model', basedir='models')
# Out:
# 2022-07-19 12:41:40.045659: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-07-19 12:41:40.057863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:40.058248: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:01.0 name: NVIDIA A40-16Q computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 84 deviceMemorySize: 15.82GiB deviceMemoryBandwidth: 648.29GiB/s
# 2022-07-19 12:41:40.058269: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-19 12:41:40.880244: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-19 12:41:40.880321: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-07-19 12:41:41.143859: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-07-19 12:41:41.266004: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-07-19 12:41:41.408910: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-07-19 12:41:41.636505: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-07-19 12:41:41.667118: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-19 12:41:41.667249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:41.667736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:41.669190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-07-19 12:41:41.669553: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-19 12:41:41.669830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:41.670196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:01.0 name: NVIDIA A40-16Q computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 84 deviceMemorySize: 15.82GiB deviceMemoryBandwidth: 648.29GiB/s
# 2022-07-19 12:41:41.670249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:41.670618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:41.670958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-07-19 12:41:41.672679: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-19 12:41:42.910220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-07-19 12:41:42.910249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-07-19 12:41:42.910255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-07-19 12:41:42.910453: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:42.910862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:42.911258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 12:41:42.911608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 12108 MB memory) -> physical GPU (device: 0, name: NVIDIA A40-16Q, pci bus id: 0000:02:01.0, compute capability: 8.6)

# %% [markdown]
# <hr style="height:2px;">
#
# # Training
#
# Training the model will likely take some time. We recommend to monitor the progress with [TensorBoard](https://www.tensorflow.org/programmers_guide/summaries_and_tensorboard) (example below), which allows you to inspect the losses during training.
# Furthermore, you can look at the predictions for some of the validation images, which can be helpful to recognize problems early on.
#
# You can start TensorBoard from the current working directory with `tensorboard --logdir=.`
# Then connect to [http://localhost:6006/](http://localhost:6006/) with your browser.
#
# ![](http://csbdeep.bioimagecomputing.com/img/tensorboard_denoising3D.png)

# %%
# Start tensorboard
#!tensorboard --logdir=. --port 6006
# Out:
# 2022-07-19 12:47:12.186600: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# /home/mattia.toninelli/miniconda3/envs/care/lib/python3.7/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 2022-07-19 13:06:17.027047: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-19 13:06:17.028370: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2949995000 Hz
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a25f80> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a25f80>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a25f80> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a25f80>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37170> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37170>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37170> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37170>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37290> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37290>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37290> and will run it as-is.
# Cause: could not parse the source code of <function _mean_or_not.<locals>.<lambda> at 0x7f8201a37290>: found multiple definitions with identical signatures at the location. This error may be avoided by defining each lambda on a single line and with unique argument names.
# Match 0:
# (lambda x: K.mean(x, axis=(- 1)))
#
# Match 1:
# (lambda x: x)
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-07-19 13:06:17.670902: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-19 13:06:28.029441: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2022-07-19 13:06:42.388878: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-19 13:06:42.388915: W tensorflow/stream_executor/gpu/asm_compiler.cc:56] Couldn't invoke ptxas --version
# 2022-07-19 13:06:42.389218: E tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-19 13:06:42.389273: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-07-19 13:06:43.075921: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-19 13:06:56.384058: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
#  6/10 [=================>............] - ETA: 0s - loss: 0.1493 - mse: 0.0566 - mae: 0.1493WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0422s vs `on_train_batch_end` time: 0.0664s). Check your callbacks.
# 10/10 [==============================] - 57s 483ms/step - loss: 0.1447 - mse: 0.0540 - mae: 0.1447 - val_loss: 0.1240 - val_mse: 0.0428 - val_mae: 0.1240
# Epoch 2/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.1268 - mse: 0.0423 - mae: 0.1268 - val_loss: 0.1067 - val_mse: 0.0333 - val_mae: 0.1067
# Epoch 3/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.1136 - mse: 0.0356 - mae: 0.1136 - val_loss: 0.1012 - val_mse: 0.0269 - val_mae: 0.1012
# Epoch 4/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.1010 - mse: 0.0286 - mae: 0.1010 - val_loss: 0.0850 - val_mse: 0.0199 - val_mae: 0.0850
# Epoch 5/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0880 - mse: 0.0206 - mae: 0.0880 - val_loss: 0.0794 - val_mse: 0.0182 - val_mae: 0.0794
# Epoch 6/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0778 - mse: 0.0177 - mae: 0.0778 - val_loss: 0.0730 - val_mse: 0.0151 - val_mae: 0.0730
# Epoch 7/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0815 - mse: 0.0184 - mae: 0.0815 - val_loss: 0.0815 - val_mse: 0.0199 - val_mae: 0.0815
# Epoch 8/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0794 - mse: 0.0183 - mae: 0.0794 - val_loss: 0.0717 - val_mse: 0.0137 - val_mae: 0.0717
# Epoch 9/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0747 - mse: 0.0170 - mae: 0.0747 - val_loss: 0.0662 - val_mse: 0.0136 - val_mae: 0.0662
# Epoch 10/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0724 - mse: 0.0154 - mae: 0.0724 - val_loss: 0.0666 - val_mse: 0.0132 - val_mae: 0.0666
# Epoch 11/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0643 - mse: 0.0127 - mae: 0.0643 - val_loss: 0.0635 - val_mse: 0.0123 - val_mae: 0.0635
# Epoch 12/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0691 - mse: 0.0143 - mae: 0.0691 - val_loss: 0.0640 - val_mse: 0.0120 - val_mae: 0.0640
# Epoch 13/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0655 - mse: 0.0132 - mae: 0.0655 - val_loss: 0.0620 - val_mse: 0.0125 - val_mae: 0.0620
# Epoch 14/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0648 - mse: 0.0135 - mae: 0.0648 - val_loss: 0.0600 - val_mse: 0.0111 - val_mae: 0.0600
# Epoch 15/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0669 - mse: 0.0137 - mae: 0.0669 - val_loss: 0.0583 - val_mse: 0.0107 - val_mae: 0.0583
# Epoch 16/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0663 - mse: 0.0133 - mae: 0.0663 - val_loss: 0.0625 - val_mse: 0.0107 - val_mae: 0.0625
# Epoch 17/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0626 - mse: 0.0119 - mae: 0.0626 - val_loss: 0.0585 - val_mse: 0.0106 - val_mae: 0.0585
# Epoch 18/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0620 - mse: 0.0124 - mae: 0.0620 - val_loss: 0.0569 - val_mse: 0.0099 - val_mae: 0.0569
# Epoch 19/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0556 - mse: 0.0105 - mae: 0.0556 - val_loss: 0.0552 - val_mse: 0.0099 - val_mae: 0.0552
# Epoch 20/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0601 - mse: 0.0115 - mae: 0.0601 - val_loss: 0.0570 - val_mse: 0.0099 - val_mae: 0.0570
# Epoch 21/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0614 - mse: 0.0119 - mae: 0.0614 - val_loss: 0.0553 - val_mse: 0.0095 - val_mae: 0.0553
# Epoch 22/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0584 - mse: 0.0108 - mae: 0.0584 - val_loss: 0.0526 - val_mse: 0.0096 - val_mae: 0.0526
# Epoch 23/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0553 - mse: 0.0100 - mae: 0.0553 - val_loss: 0.0522 - val_mse: 0.0095 - val_mae: 0.0522
# Epoch 24/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0543 - mse: 0.0097 - mae: 0.0543 - val_loss: 0.0499 - val_mse: 0.0085 - val_mae: 0.0499
# Epoch 25/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0524 - mse: 0.0092 - mae: 0.0524 - val_loss: 0.0480 - val_mse: 0.0079 - val_mae: 0.0480
# Epoch 26/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0526 - mse: 0.0092 - mae: 0.0526 - val_loss: 0.0488 - val_mse: 0.0081 - val_mae: 0.0488
# Epoch 27/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0521 - mse: 0.0092 - mae: 0.0521 - val_loss: 0.0475 - val_mse: 0.0077 - val_mae: 0.0475
# Epoch 28/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0515 - mse: 0.0088 - mae: 0.0515 - val_loss: 0.0491 - val_mse: 0.0075 - val_mae: 0.0491
# Epoch 29/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0523 - mse: 0.0090 - mae: 0.0523 - val_loss: 0.0482 - val_mse: 0.0079 - val_mae: 0.0482
# Epoch 30/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0485 - mse: 0.0082 - mae: 0.0485 - val_loss: 0.0475 - val_mse: 0.0074 - val_mae: 0.0475
# Epoch 31/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0497 - mse: 0.0083 - mae: 0.0497 - val_loss: 0.0471 - val_mse: 0.0076 - val_mae: 0.0471
# Epoch 32/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0512 - mse: 0.0089 - mae: 0.0512 - val_loss: 0.0455 - val_mse: 0.0071 - val_mae: 0.0455
# Epoch 33/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0499 - mse: 0.0083 - mae: 0.0499 - val_loss: 0.0488 - val_mse: 0.0072 - val_mae: 0.0488
# Epoch 34/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0510 - mse: 0.0085 - mae: 0.0510 - val_loss: 0.0464 - val_mse: 0.0073 - val_mae: 0.0464
# Epoch 35/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0508 - mse: 0.0085 - mae: 0.0508 - val_loss: 0.0468 - val_mse: 0.0078 - val_mae: 0.0468
# Epoch 36/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0498 - mse: 0.0082 - mae: 0.0498 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464
# Epoch 37/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0480 - mse: 0.0082 - mae: 0.0480 - val_loss: 0.0456 - val_mse: 0.0072 - val_mae: 0.0456
# Epoch 38/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0476 - mse: 0.0078 - mae: 0.0476 - val_loss: 0.0456 - val_mse: 0.0074 - val_mae: 0.0456
# Epoch 39/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0507 - mse: 0.0085 - mae: 0.0507 - val_loss: 0.0472 - val_mse: 0.0081 - val_mae: 0.0472
# Epoch 40/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0486 - mse: 0.0082 - mae: 0.0486 - val_loss: 0.0453 - val_mse: 0.0070 - val_mae: 0.0453
# Epoch 41/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0477 - mse: 0.0076 - mae: 0.0477 - val_loss: 0.0438 - val_mse: 0.0066 - val_mae: 0.0438
# Epoch 42/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0435 - mse: 0.0067 - mae: 0.0435 - val_loss: 0.0433 - val_mse: 0.0066 - val_mae: 0.0433
# Epoch 43/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0494 - mse: 0.0081 - mae: 0.0494 - val_loss: 0.0431 - val_mse: 0.0065 - val_mae: 0.0431
# Epoch 44/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - val_loss: 0.0445 - val_mse: 0.0065 - val_mae: 0.0445
# Epoch 45/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0453 - mse: 0.0072 - mae: 0.0453 - val_loss: 0.0438 - val_mse: 0.0064 - val_mae: 0.0438
# Epoch 46/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0488 - mse: 0.0078 - mae: 0.0488 - val_loss: 0.0439 - val_mse: 0.0064 - val_mae: 0.0439
# Epoch 47/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0528 - mse: 0.0089 - mae: 0.0528 - val_loss: 0.0532 - val_mse: 0.0076 - val_mae: 0.0532
# Epoch 48/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0537 - mse: 0.0091 - mae: 0.0537 - val_loss: 0.0445 - val_mse: 0.0071 - val_mae: 0.0445
# Epoch 49/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0487 - mse: 0.0080 - mae: 0.0487 - val_loss: 0.0441 - val_mse: 0.0069 - val_mae: 0.0441
# Epoch 50/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0466 - mse: 0.0074 - mae: 0.0466 - val_loss: 0.0428 - val_mse: 0.0064 - val_mae: 0.0428
# Epoch 51/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0413 - mse: 0.0064 - mae: 0.0413 - val_loss: 0.0421 - val_mse: 0.0063 - val_mae: 0.0421
# Epoch 52/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0442 - mse: 0.0067 - mae: 0.0442 - val_loss: 0.0432 - val_mse: 0.0063 - val_mae: 0.0432
# Epoch 53/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0472 - mse: 0.0074 - mae: 0.0472 - val_loss: 0.0432 - val_mse: 0.0064 - val_mae: 0.0432
# Epoch 54/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0447 - mse: 0.0069 - mae: 0.0447 - val_loss: 0.0439 - val_mse: 0.0072 - val_mae: 0.0439
# Epoch 55/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0499 - mse: 0.0083 - mae: 0.0499 - val_loss: 0.0435 - val_mse: 0.0065 - val_mae: 0.0435
# Epoch 56/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0472 - mse: 0.0074 - mae: 0.0472 - val_loss: 0.0435 - val_mse: 0.0061 - val_mae: 0.0435
# Epoch 57/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0468 - mse: 0.0073 - mae: 0.0468 - val_loss: 0.0426 - val_mse: 0.0062 - val_mae: 0.0426
# Epoch 58/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0442 - mse: 0.0067 - mae: 0.0442 - val_loss: 0.0429 - val_mse: 0.0064 - val_mae: 0.0429
# Epoch 59/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0475 - mse: 0.0075 - mae: 0.0475 - val_loss: 0.0412 - val_mse: 0.0060 - val_mae: 0.0412
# Epoch 60/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0446 - mse: 0.0068 - mae: 0.0446 - val_loss: 0.0411 - val_mse: 0.0059 - val_mae: 0.0411
# Epoch 61/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0415 - mse: 0.0061 - mae: 0.0415 - val_loss: 0.0410 - val_mse: 0.0061 - val_mae: 0.0410
# Epoch 62/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0412 - mse: 0.0061 - mae: 0.0412 - val_loss: 0.0412 - val_mse: 0.0059 - val_mae: 0.0412
# Epoch 63/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0450 - mse: 0.0069 - mae: 0.0450 - val_loss: 0.0422 - val_mse: 0.0063 - val_mae: 0.0422
# Epoch 64/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0432 - mse: 0.0064 - mae: 0.0432 - val_loss: 0.0408 - val_mse: 0.0059 - val_mae: 0.0408
# Epoch 65/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0442 - mse: 0.0065 - mae: 0.0442 - val_loss: 0.0407 - val_mse: 0.0058 - val_mae: 0.0407
# Epoch 66/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0431 - mse: 0.0064 - mae: 0.0431 - val_loss: 0.0416 - val_mse: 0.0058 - val_mae: 0.0416
# Epoch 67/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0465 - mse: 0.0072 - mae: 0.0465 - val_loss: 0.0404 - val_mse: 0.0058 - val_mae: 0.0404
# Epoch 68/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0419 - mse: 0.0061 - mae: 0.0419 - val_loss: 0.0409 - val_mse: 0.0057 - val_mae: 0.0409
# Epoch 69/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0426 - mse: 0.0064 - mae: 0.0426 - val_loss: 0.0413 - val_mse: 0.0057 - val_mae: 0.0413
# Epoch 70/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0419 - mse: 0.0061 - mae: 0.0419 - val_loss: 0.0434 - val_mse: 0.0059 - val_mae: 0.0434
# Epoch 71/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0428 - mse: 0.0063 - mae: 0.0428 - val_loss: 0.0407 - val_mse: 0.0057 - val_mae: 0.0407
# Epoch 72/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0446 - mse: 0.0066 - mae: 0.0446 - val_loss: 0.0404 - val_mse: 0.0057 - val_mae: 0.0404
# Epoch 73/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0439 - mse: 0.0065 - mae: 0.0439 - val_loss: 0.0398 - val_mse: 0.0056 - val_mae: 0.0398
# Epoch 74/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0412 - mse: 0.0059 - mae: 0.0412 - val_loss: 0.0410 - val_mse: 0.0059 - val_mae: 0.0410
# Epoch 75/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0423 - mse: 0.0061 - mae: 0.0423 - val_loss: 0.0406 - val_mse: 0.0058 - val_mae: 0.0406
# Epoch 76/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0388 - mse: 0.0053 - mae: 0.0388 - val_loss: 0.0405 - val_mse: 0.0056 - val_mae: 0.0405
# Epoch 77/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0422 - mse: 0.0061 - mae: 0.0422 - val_loss: 0.0399 - val_mse: 0.0056 - val_mae: 0.0399
# Epoch 78/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0453 - mse: 0.0067 - mae: 0.0453 - val_loss: 0.0403 - val_mse: 0.0058 - val_mae: 0.0403
# Epoch 79/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0422 - mse: 0.0060 - mae: 0.0422 - val_loss: 0.0393 - val_mse: 0.0054 - val_mae: 0.0393
# Epoch 80/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0401 - mse: 0.0057 - mae: 0.0401 - val_loss: 0.0396 - val_mse: 0.0056 - val_mae: 0.0396
# Epoch 81/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0443 - mse: 0.0065 - mae: 0.0443 - val_loss: 0.0394 - val_mse: 0.0056 - val_mae: 0.0394
# Epoch 82/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0404 - mse: 0.0056 - mae: 0.0404 - val_loss: 0.0410 - val_mse: 0.0055 - val_mae: 0.0410
# Epoch 83/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0412 - mse: 0.0058 - mae: 0.0412 - val_loss: 0.0390 - val_mse: 0.0053 - val_mae: 0.0390
# Epoch 84/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0394 - mse: 0.0054 - mae: 0.0394 - val_loss: 0.0389 - val_mse: 0.0054 - val_mae: 0.0389
# Epoch 85/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0427 - mse: 0.0061 - mae: 0.0427 - val_loss: 0.0398 - val_mse: 0.0055 - val_mae: 0.0398
# Epoch 86/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0429 - mse: 0.0062 - mae: 0.0429 - val_loss: 0.0390 - val_mse: 0.0054 - val_mae: 0.0390
# Epoch 87/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0458 - mse: 0.0068 - mae: 0.0458 - val_loss: 0.0447 - val_mse: 0.0070 - val_mae: 0.0447
# Epoch 88/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0415 - mse: 0.0059 - mae: 0.0415 - val_loss: 0.0402 - val_mse: 0.0055 - val_mae: 0.0402
# Epoch 89/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0421 - mse: 0.0060 - mae: 0.0421 - val_loss: 0.0401 - val_mse: 0.0053 - val_mae: 0.0401
# Epoch 90/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0411 - mse: 0.0057 - mae: 0.0411 - val_loss: 0.0422 - val_mse: 0.0056 - val_mae: 0.0422
# Epoch 91/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0418 - mse: 0.0058 - mae: 0.0418 - val_loss: 0.0394 - val_mse: 0.0054 - val_mae: 0.0394
# Epoch 92/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0404 - mse: 0.0055 - mae: 0.0404 - val_loss: 0.0386 - val_mse: 0.0052 - val_mae: 0.0386
# Epoch 93/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0406 - mse: 0.0055 - mae: 0.0406 - val_loss: 0.0384 - val_mse: 0.0051 - val_mae: 0.0384
# Epoch 94/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0384 - mse: 0.0050 - mae: 0.0384 - val_loss: 0.0386 - val_mse: 0.0053 - val_mae: 0.0386
# Epoch 95/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0383 - mse: 0.0051 - mae: 0.0383 - val_loss: 0.0382 - val_mse: 0.0052 - val_mae: 0.0382
# Epoch 96/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0396 - mse: 0.0053 - mae: 0.0396 - val_loss: 0.0387 - val_mse: 0.0053 - val_mae: 0.0387
# Epoch 97/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0397 - mse: 0.0053 - mae: 0.0397 - val_loss: 0.0383 - val_mse: 0.0052 - val_mae: 0.0383
# Epoch 98/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0401 - mse: 0.0054 - mae: 0.0401 - val_loss: 0.0394 - val_mse: 0.0051 - val_mae: 0.0394
# Epoch 99/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0383 - mse: 0.0050 - mae: 0.0383 - val_loss: 0.0392 - val_mse: 0.0053 - val_mae: 0.0392
# Epoch 100/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0404 - mse: 0.0054 - mae: 0.0404 - val_loss: 0.0390 - val_mse: 0.0053 - val_mae: 0.0390
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# Plot final training history (available in TensorBoard during training):

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %% [markdown]
# <hr style="height:2px;">
#
# # Evaluation
#
# Example results for validation images.

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %% [markdown]
# <hr style="height:2px;">
#
# # Export model to be used with CSBDeep **Fiji** plugins and **KNIME** workflows
#
# See https://github.com/CSBDeep/CSBDeep_website/wiki/Your-Model-in-Fiji for details.

# %%
model.export_TF()
# Out:
# 2022-07-19 14:03:11.907974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 14:03:11.908140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:01.0 name: NVIDIA A40-16Q computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 84 deviceMemorySize: 15.82GiB deviceMemoryBandwidth: 648.29GiB/s
# 2022-07-19 14:03:11.908193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 14:03:11.908332: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 14:03:11.908441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-07-19 14:03:11.908472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-07-19 14:03:11.908480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-07-19 14:03:11.908484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-07-19 14:03:11.908544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 14:03:11.908694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-19 14:03:11.908809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 12108 MB memory) -> physical GPU (device: 0, name: NVIDIA A40-16Q, pci bus id: 0000:02:01.0, compute capability: 8.6)
# WARNING:tensorflow:From /home/mattia.toninelli/miniconda3/envs/care/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmplewlz7w_/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /home/mattia.toninelli/DL4MIA/CSBDeep/examples/denoising3D/models/my_model/TF_SavedModel.zip
